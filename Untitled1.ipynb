# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("retail_sales.csv")

df.head()
# Out:
#   Transaction ID        Date Customer ID  Gender  Age       Product  \
# 0         T00384  2023-02-07        C063    Male   35       T-Shirt
# 1         T00383  2023-02-22        C062    Male   43  Office Chair
# 2         T00403  2023-02-25        C074    Male   61       Blender
# 3         T00387  2023-03-11        C066    Male   64        Jacket
# 4         T00386  2023-03-19        C065  Female   23   Rice Cooker
#
#          Category  Quantity    Price  Total Amount
# 0        Clothing         1   919.89        919.89
# 1       Furniture         1  6748.56       6748.56
# 2  Home & Kitchen         1  2997.20       2997.20
# 3        Clothing         2  4947.01       9894.02
# 4  Home & Kitchen         1  3746.67       3746.67

# %%
print("Dataset Shape:", df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

print("\nDataset Information:")
df.info()
# Out:
# Dataset Shape: (417, 10)
#
# Column Names:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age', 'Product',
#        'Category', 'Quantity', 'Price', 'Total Amount'],
#       dtype='object')
#
# Data Types:
# Transaction ID     object
# Date               object
# Customer ID        object
# Gender             object
# Age                 int64
# Product            object
# Category           object
# Quantity            int64
# Price             float64
# Total Amount      float64
# dtype: object
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction ID  417 non-null    object
#  1   Date            417 non-null    object
#  2   Customer ID     417 non-null    object
#  3   Gender          417 non-null    object
#  4   Age             417 non-null    int64
#  5   Product         417 non-null    object
#  6   Category        417 non-null    object
#  7   Quantity        417 non-null    int64
#  8   Price           417 non-null    float64
#  9   Total Amount    417 non-null    float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 32.7+ KB

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Transaction ID    0
# Date              0
# Customer ID       0
# Gender            0
# Age               0
# Product           0
# Category          0
# Quantity          0
# Price             0
# Total Amount      0
# dtype: int64

# %%
numeric_df = df.select_dtypes(include=np.number)

print("Mean:")
print(numeric_df.mean())

print("\nMedian:")
print(numeric_df.median())

print("\nMode:")
print(numeric_df.mode().iloc[0])

print("\nStandard Deviation:")
print(numeric_df.std())

print("\nComplete Descriptive Statistics:")
print(numeric_df.describe())
# Out:
# Mean:
# Age                42.095923
# Quantity            1.892086
# Price           15418.298777
# Total Amount    29901.009928
# dtype: float64
#
# Median:
# Age               40.00
# Quantity           2.00
# Price           3037.91
# Total Amount    6428.40
# dtype: float64
#
# Mode:
# Age              25.00
# Quantity          2.00
# Price           813.89
# Total Amount    827.43
# Name: 0, dtype: float64
#
# Standard Deviation:
# Age                13.432896
# Quantity            0.740556
# Price           22579.099781
# Total Amount    48933.618096
# dtype: float64
#
# Complete Descriptive Statistics:
#               Age    Quantity         Price   Total Amount
# count  417.000000  417.000000    417.000000     417.000000
# mean    42.095923    1.892086  15418.298777   29901.009928
# std     13.432896    0.740556  22579.099781   48933.618096
# min     18.000000    1.000000    813.890000     827.430000
# 25%     29.000000    1.000000   2154.650000    2996.750000
# 50%     40.000000    2.000000   3037.910000    6428.400000
# 75%     55.000000    2.000000  28052.080000   31218.200000
# max     65.000000    3.000000  71061.010000  211224.450000

# %%
df["Date"] = pd.to_datetime(df["Date"])

df["Month"] = df["Date"].dt.to_period("M")

df["Quarter"] = df["Date"].dt.to_period("Q")

# %%
monthly_sales = df.groupby("Month")["Total Amount"].sum()

plt.figure(figsize=(12, 6))

monthly_sales.plot(
    kind="line",
    marker="o"
)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.grid()

plt.show()

# %%
quarterly_sales = df.groupby("Quarter")["Total Amount"].sum()

plt.figure(figsize=(10, 6))

quarterly_sales.plot(
    kind="line",
    marker="o"
)

plt.title("Quarterly Sales Trend")
plt.xlabel("Quarter")
plt.ylabel("Total Sales")

plt.grid()

plt.show()

# %%
bins = [0, 18, 25, 35, 45, 60, 100]

labels = [
    "Below 18",
    "18-25",
    "26-35",
    "36-45",
    "46-60",
    "60+"
]

df["Age Group"] = pd.cut(
    df["Age"],
    bins=bins,
    labels=labels
)

# %%
plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    x="Age Group"
)

plt.title("Customer Age Group Distribution")
plt.xlabel("Age Group")
plt.ylabel("Number of Customers")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="Gender"
)

plt.title("Customer Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")

plt.show()

# %%
top_products = (
    df.groupby("Product")["Quantity"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(top_products)
# Out:
# Product
# Laptop          122
# Jeans           107
# Smartphone       97
# T-Shirt          88
# Blender          77
# Desk Lamp        66
# Jacket           64
# Rice Cooker      63
# Headphones       56
# Office Chair     49
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize=(12, 6))

top_products.plot(
    kind="bar"
)

plt.title("Top 10 Best-Selling Products")
plt.xlabel("Product")
plt.ylabel("Quantity Sold")

plt.xticks(rotation=45)

plt.show()

# %%
category_revenue = (
    df.groupby("Category")["Total Amount"]
    .sum()
    .sort_values(ascending=False)
)

print(category_revenue)
# Out:
# Category
# Electronics       10964522.44
# Clothing            608347.94
# Furniture           454539.86
# Home & Kitchen      441310.90
# Name: Total Amount, dtype: float64

# %%
plt.figure(figsize=(10, 6))

category_revenue.plot(
    kind="bar"
)

plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")

plt.xticks(rotation=45)

plt.show()

# %%
numeric_columns = df.select_dtypes(include=np.number)

plt.figure(figsize=(10, 8))

sns.heatmap(
    numeric_columns.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix of Numerical Variables")

plt.show()

# %%
gender_sales = (
    df.groupby("Gender")["Total Amount"]
    .sum()
)

plt.figure(figsize=(8, 5))

gender_sales.plot(
    kind="bar"
)

plt.title("Total Sales by Gender")
plt.xlabel("Gender")
plt.ylabel("Total Sales")

plt.show()
